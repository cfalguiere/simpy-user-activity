# %%
# !pip install simpy plotly
# Out:
# Requirement already satisfied: simpy in /Users/cfalguiere/anaconda3/lib/python3.7/site-packages (4.0.1)
# Requirement already satisfied: plotly in /Users/cfalguiere/anaconda3/lib/python3.7/site-packages (5.3.1)
# Requirement already satisfied: six in /Users/cfalguiere/anaconda3/lib/python3.7/site-packages (from plotly) (1.12.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/cfalguiere/anaconda3/lib/python3.7/site-packages (from plotly) (8.0.1)

# %%
import simpy

# %%
#

# %%
class SystemResource(simpy.Resource):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        print(args)
        print(kwargs)
        print(f"create resource with capacity {self.capacity}")
        self.processing_data = []
        self.waiting_data = []

    def request(self, *args, **kwargs):
        print("request resource at %d" % self._env.now)
        # start with len(self.queue as documented
        print(f"{len(self.queue)} waiting at %d" % self._env.now)
        # but only shows queue
        # attention users et pas resources
        # attention compteur mesuré a avant (donc 0)
        print(f"{self.count} processing at %d" % self._env.now)
        self.processing_data.append((self._env.now, self.count))
        self.waiting_data.append((self._env.now, len(self.queue)))
        return super().request(*args, **kwargs)

    def release(self, *args, **kwargs):
        print("release resource at %d" % self._env.now)
        print(f"{len(self.queue)} waiting at %d" % self._env.now)
        # attention compteur mesuré a avant (donc 1)
        print(f"{self.count} processing at %d" % self._env.now)
        self.processing_data.append((self._env.now, self.count))
        self.waiting_data.append((self._env.now, len(self.queue)))
        return super().release(*args, **kwargs)

# %%
class User():
    def __init__(self, id, env, res, monitor):
        self.id = id
        self.env = env
        self.res = res
        self.monitor = monitor
        # ajoute apres sinon chevauchement
        self.taskid = 1
        self.name = f"User-{id}"
        # Start the run process everytime an instance is created.
        # create itself as a processs
        self.action = env.process(self.run())

    def run(self):
        while True:
            taskname = "process_task"
            self.taskid += 1
            self.monitor.report_start(self.name, taskname, self.taskid)
            print(f"{self.name} starts task at %d" % self.env.now)
            task_duration = 5
            # We yield the process that process() returns
            # to wait for it to finish
            yield self.env.process(self.process_task(task_duration))
            print(f"{self.name} ends task at %d" % self.env.now)
            self.monitor.report_stop(self.name, taskname, self.taskid)
     
            # The charge process has finished and
            # we can start driving again.
            print(f"{self.name} starts verification at %d" % self.env.now)
            verification_duration = 2
            yield self.env.timeout(verification_duration)
            print(f"{self.name} ends verification at %d" % self.env.now)

    def process_task(self, duration):
        with self.res.request() as req:
            yield req
            yield self.env.timeout(duration)

# %%
import datetime
class Clock:
    def __init__(self):
        #self.base_epoch = datetime.datetime(2021,9,10,0,0).timestamp()
        self.base_epoch = datetime.datetime.now().timestamp()
        print(f"Clock created - base {self.base_epoch}")

    def to_date(self, tick):
        epoch_time = self.base_epoch + tick*60 #mn
        #print(f"Clock {epoch_time}")
        datetime_time = datetime.datetime.fromtimestamp(epoch_time)
        return datetime_time

# %%
clock = Clock()
# Out:
# Clock created - base 1631380468.956452

# %%
import pandas as pd
class UsersMonitor:
    def __init__(self, env, clock):
        self.env = env
        self.start_data = []
        self.stop_data = []
        
    def report_start(self, username, taskname, taskid):
        mark = self.env.now
        self.start_data.append(
            dict(  
                StartMark=mark,
                Start=clock.to_date(mark),
                Username=username,
                Task=taskname,
                TaskId=taskid
            )
        )       
        
    def report_stop(self, username, taskname, taskid):
        mark = self.env.now
        self.stop_data.append(
            dict(  
                FinishMark=mark,
                Finish=clock.to_date(mark),
                Username=username,
                Task=taskname,
                TaskId=taskid
            )
        )
        
                
    def collect(self):
        df_start = pd.DataFrame(self.start_data)
        df_stop = pd.DataFrame(self.stop_data)
        df = pd.merge(df_start, df_stop, how='left', 
                      on = ['Username', 'Task', 'TaskId'])
        return df

# %%
env = simpy.Environment()

user_monitor = UsersMonitor(env, clock)
res = SystemResource(env, capacity=1)
user = User(1, env, res, user_monitor)
env.run(until=15)

print("Processing")
print(res.processing_data)
print("Waiting")
print(res.waiting_data)
# Out:
# (<simpy.core.Environment object at 0x10c424b70>,)
# {'capacity': 1}
# create resource with capacity 1
# User-1 starts task at 0
# request resource at 0
# 0 waiting at 0
# 0 processing at 0
# release resource at 5
# 0 waiting at 5
# 1 processing at 5
# User-1 ends task at 5
# User-1 starts verification at 5
# User-1 ends verification at 7
# User-1 starts task at 7
# request resource at 7
# 0 waiting at 7
# 0 processing at 7
# release resource at 12
# 0 waiting at 12
# 1 processing at 12
# User-1 ends task at 12
# User-1 starts verification at 12
# User-1 ends verification at 14
# User-1 starts task at 14
# request resource at 14
# 0 waiting at 14
# 0 processing at 14
# Processing
# [(0, 0), (5, 1), (7, 0), (12, 1), (14, 0)]
# Waiting
# [(0, 0), (5, 0), (7, 0), (12, 0), (14, 0)]

# %%
def user_generator(size, env, res, user_monitor):
    for i in range(size):
        User(i, env, res, user_monitor).action
        yield env.timeout(5)

# %%
# au passage suppression de magix numbers
sim_duration = 100
nb_users = 20

env = simpy.Environment()
user_monitor = UsersMonitor(env, clock)
res = SystemResource(env, capacity=1)
#user = User(env, res)
user_gen = env.process(user_generator(nb_users, env, res, user_monitor))

env.run(until=sim_duration)
# Out:
# (<simpy.core.Environment object at 0x10c432fd0>,)
# {'capacity': 1}
# create resource with capacity 1
# User-0 starts task at 0
# request resource at 0
# 0 waiting at 0
# 0 processing at 0
# User-1 starts task at 5
# request resource at 5
# 0 waiting at 5
# 1 processing at 5
# release resource at 5
# 1 waiting at 5
# 1 processing at 5
# User-0 ends task at 5
# User-0 starts verification at 5
# User-0 ends verification at 7
# User-0 starts task at 7
# request resource at 7
# 0 waiting at 7
# 1 processing at 7
# User-2 starts task at 10
# request resource at 10
# 1 waiting at 10
# 1 processing at 10
# release resource at 10
# 2 waiting at 10
# 1 processing at 10
# User-1 ends task at 10
# User-1 starts verification at 10
# User-1 ends verification at 12
# User-1 starts task at 12
# request resource at 12
# 1 waiting at 12
# 1 processing at 12
# User-3 starts task at 15
# request resource at 15
# 2 waiting at 15
# 1 processing at 15
# release resource at 15
# 3 waiting at 15
# 1 processing at 15
# User-0 ends task at 15
# User-0 starts verification at 15
# User-0 ends verification at 17
# User-0 starts task at 17
# request resource at 17
# 2 waiting at 17
# 1 processing at 17
# User-4 starts task at 20
# request resource at 20
# 3 waiting at 20
# 1 processing at 20
# release resource at 20
# 4 waiting at 20
# 1 processing at 20
# User-2 ends task at 20
# User-2 starts verification at 20
# User-2 ends verification at 22
# User-2 starts task at 22
# request resource at 22
# 3 waiting at 22
# 1 processing at 22
# User-5 starts task at 25
# request resource at 25
# 4 waiting at 25
# 1 processing at 25
# release resource at 25
# 5 waiting at 25
# 1 processing at 25
# User-1 ends task at 25
# User-1 starts verification at 25
# User-1 ends verification at 27
# User-1 starts task at 27
# request resource at 27
# 4 waiting at 27
# 1 processing at 27
# User-6 starts task at 30
# request resource at 30
# 5 waiting at 30
# 1 processing at 30
# release resource at 30
# 6 waiting at 30
# 1 processing at 30
# User-3 ends task at 30
# User-3 starts verification at 30
# User-3 ends verification at 32
# User-3 starts task at 32
# request resource at 32
# 5 waiting at 32
# 1 processing at 32
# User-7 starts task at 35
# request resource at 35
# 6 waiting at 35
# 1 processing at 35
# release resource at 35
# 7 waiting at 35
# 1 processing at 35
# User-0 ends task at 35
# User-0 starts verification at 35
# User-0 ends verification at 37
# User-0 starts task at 37
# request resource at 37
# 6 waiting at 37
# 1 processing at 37
# User-8 starts task at 40
# request resource at 40
# 7 waiting at 40
# 1 processing at 40
# release resource at 40
# 8 waiting at 40
# 1 processing at 40
# User-4 ends task at 40
# User-4 starts verification at 40
# User-4 ends verification at 42
# User-4 starts task at 42
# request resource at 42
# 7 waiting at 42
# 1 processing at 42
# User-9 starts task at 45
# request resource at 45
# 8 waiting at 45
# 1 processing at 45
# release resource at 45
# 9 waiting at 45
# 1 processing at 45
# User-2 ends task at 45
# User-2 starts verification at 45
# User-2 ends verification at 47
# User-2 starts task at 47
# request resource at 47
# 8 waiting at 47
# 1 processing at 47
# User-10 starts task at 50
# request resource at 50
# 9 waiting at 50
# 1 processing at 50
# release resource at 50
# 10 waiting at 50
# 1 processing at 50
# User-5 ends task at 50
# User-5 starts verification at 50
# User-5 ends verification at 52
# User-5 starts task at 52
# request resource at 52
# 9 waiting at 52
# 1 processing at 52
# User-11 starts task at 55
# request resource at 55
# 10 waiting at 55
# 1 processing at 55
# release resource at 55
# 11 waiting at 55
# 1 processing at 55
# User-1 ends task at 55
# User-1 starts verification at 55
# User-1 ends verification at 57
# User-1 starts task at 57
# request resource at 57
# 10 waiting at 57
# 1 processing at 57
# User-12 starts task at 60
# request resource at 60
# 11 waiting at 60
# 1 processing at 60
# release resource at 60
# 12 waiting at 60
# 1 processing at 60
# User-6 ends task at 60
# User-6 starts verification at 60
# User-6 ends verification at 62
# User-6 starts task at 62
# request resource at 62
# 11 waiting at 62
# 1 processing at 62
# User-13 starts task at 65
# request resource at 65
# 12 waiting at 65
# 1 processing at 65
# release resource at 65
# 13 waiting at 65
# 1 processing at 65
# User-3 ends task at 65
# User-3 starts verification at 65
# User-3 ends verification at 67
# User-3 starts task at 67
# request resource at 67
# 12 waiting at 67
# 1 processing at 67
# User-14 starts task at 70
# request resource at 70
# 13 waiting at 70
# 1 processing at 70
# release resource at 70
# 14 waiting at 70
# 1 processing at 70
# User-7 ends task at 70
# User-7 starts verification at 70
# User-7 ends verification at 72
# User-7 starts task at 72
# request resource at 72
# 13 waiting at 72
# 1 processing at 72
# User-15 starts task at 75
# request resource at 75
# 14 waiting at 75
# 1 processing at 75
# release resource at 75
# 15 waiting at 75
# 1 processing at 75
# User-0 ends task at 75
# User-0 starts verification at 75
# User-0 ends verification at 77
# User-0 starts task at 77
# request resource at 77
# 14 waiting at 77
# 1 processing at 77
# User-16 starts task at 80
# request resource at 80
# 15 waiting at 80
# 1 processing at 80
# release resource at 80
# 16 waiting at 80
# 1 processing at 80
# User-8 ends task at 80
# User-8 starts verification at 80
# User-8 ends verification at 82
# User-8 starts task at 82
# request resource at 82
# 15 waiting at 82
# 1 processing at 82
# User-17 starts task at 85
# request resource at 85
# 16 waiting at 85
# 1 processing at 85
# release resource at 85
# 17 waiting at 85
# 1 processing at 85
# User-4 ends task at 85
# User-4 starts verification at 85
# User-4 ends verification at 87
# User-4 starts task at 87
# request resource at 87
# 16 waiting at 87
# 1 processing at 87
# User-18 starts task at 90
# request resource at 90
# 17 waiting at 90
# 1 processing at 90
# release resource at 90
# 18 waiting at 90
# 1 processing at 90
# User-9 ends task at 90
# User-9 starts verification at 90
# User-9 ends verification at 92
# User-9 starts task at 92
# request resource at 92
# 17 waiting at 92
# 1 processing at 92
# User-19 starts task at 95
# request resource at 95
# 18 waiting at 95
# 1 processing at 95
# release resource at 95
# 19 waiting at 95
# 1 processing at 95
# User-2 ends task at 95
# User-2 starts verification at 95
# User-2 ends verification at 97
# User-2 starts task at 97
# request resource at 97
# 18 waiting at 97
# 1 processing at 97

# %%
print("Processing")
print(res.processing_data)
# Out:
# Processing
# [(0, 0), (5, 1), (5, 1), (7, 1), (10, 1), (10, 1), (12, 1), (15, 1), (15, 1), (17, 1), (20, 1), (20, 1), (22, 1), (25, 1), (25, 1), (27, 1), (30, 1), (30, 1), (32, 1), (35, 1), (35, 1), (37, 1), (40, 1), (40, 1), (42, 1), (45, 1), (45, 1), (47, 1), (50, 1), (50, 1), (52, 1), (55, 1), (55, 1), (57, 1), (60, 1), (60, 1), (62, 1), (65, 1), (65, 1), (67, 1), (70, 1), (70, 1), (72, 1), (75, 1), (75, 1), (77, 1), (80, 1), (80, 1), (82, 1), (85, 1), (85, 1), (87, 1), (90, 1), (90, 1), (92, 1), (95, 1), (95, 1), (97, 1)]

# %%
print("Waiting")
print(res.waiting_data)
# Out:
# Waiting
# [(0, 0), (5, 0), (5, 1), (7, 0), (10, 1), (10, 2), (12, 1), (15, 2), (15, 3), (17, 2), (20, 3), (20, 4), (22, 3), (25, 4), (25, 5), (27, 4), (30, 5), (30, 6), (32, 5), (35, 6), (35, 7), (37, 6), (40, 7), (40, 8), (42, 7), (45, 8), (45, 9), (47, 8), (50, 9), (50, 10), (52, 9), (55, 10), (55, 11), (57, 10), (60, 11), (60, 12), (62, 11), (65, 12), (65, 13), (67, 12), (70, 13), (70, 14), (72, 13), (75, 14), (75, 15), (77, 14), (80, 15), (80, 16), (82, 15), (85, 16), (85, 17), (87, 16), (90, 17), (90, 18), (92, 17), (95, 18), (95, 19), (97, 18)]
